# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.0/612.0 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect val model=yolov8m.pt data=coco.yaml
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 64.3MB/s]
# Ultralytics YOLOv8.0.156 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/content/datasets/coco/val2017.txt'
# ...
# 100% 169M/169M [00:02<00:00, 84.9MB/s]
# Unzipping /content/datasets/coco2017labels-segments.zip to /content/datasets...: 100% 122232/122232 [00:22<00:00, 5496.99file/s]
# ...
# Dataset download success ✅ (678.0s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 22.5MB/s]
# val: Scanning /content/datasets/coco/labels/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:15<00:00, 314.38it/s]
# val: New cache created: /content/datasets/coco/labels/val2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 313/313 [1:57:13<00:00, 22.47s/it]
# ...
